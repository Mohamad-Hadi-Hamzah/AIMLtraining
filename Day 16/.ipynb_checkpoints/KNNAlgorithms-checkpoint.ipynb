# %% [markdown]
# # KNN Algorithm is Supervised Machine Learning
# # KNeighbourClassifier of sklearn library for this one

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
X = np.array([
    [1, 3500],
    [2, 3200],
    [3, 3000],
    [4, 2500],
    [5, 2300],
    [6, 2000],
    [7, 2200],
    [8, 3700],
])
y = ['Unfit','Unfit','Unfit','Fit','Fit','Fit','Fit','Unfit']

# %%
model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
new_person=[[4.5,2600]]
pred=model.predict(new_person)
print('Predicted result: ',pred[0])
# Out:
# Predicted result:  Fit

# %%
exercise_hours=float(input('Enter Number of Exercise Hours: '))
cal_intake=int(input('Enter Number of Calories Consumed: '))
pred_fu=model.predict([[exercise_hours,cal_intake]])
print(f'Exercise Hours {exercise_hours}, Calories Intake {cal_intake}, You are likely {pred_fu[0]}')
# Out:
# Enter Number of Exercise Hours:  3
# Enter Number of Calories Consumed:  3500
# Exercise Hours 3.0, Calories Intake 3500, You are likely Unfit

# %%
import pandas as pd

# %%
df=pd.read_csv('fruit_data.csv')
df
# Out:
#    Weight  Size   Fruit
# 0     150   7.0   Apple
# 1     160   7.2   Apple
# 2     200   8.0  Orange
# 3     210   8.2  Orange
# 4     180   7.5       ?

# %%
X=df[['Weight','Size']]
y=df['Fruit']

# %%
model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
fruit_w=float(input('Enter Fruit Weight: '))
fruit_s=float(input('Enter Fruit Size: '))
#pred_fruit=model.predict([[fruit_w,fruit_s]])
new_fruit=pd.DataFrame([[fruit_w,fruit_s]],columns=['Weight','Size'])
pred_fruit=model.predict(new_fruit)
print(f'Fruit weight {fruit_w} with fruit size {fruit_s}, is likely an {pred_fruit[0]}')
# Out:
# Enter Fruit Weight:  100
# Enter Fruit Size:  7
# Fruit weight 100.0 with fruit size 7.0, is likely an Apple

# %% [markdown]
# # Downlaod student_grade.csv from GitHub.com
#     Predict a student's grade level (A, B, or C)
#     based on hours studied and assignments completed
#     using the K-Nearest Neighbors algorithm

# %%
df=pd.read_csv('student_grade.csv')
df
# Out:
#    Hours_Studied  Assignments_Completed Grade
# 0            1.5                      1     C
# 1            2.0                      2     C
# 2            3.0                      3     B
# 3            4.0                      4     B
# 4            5.0                      5     A
# 5            6.0                      6     A

# %%
effort=df[['Hours_Studied','Assignments_Completed']]
grade=df['Grade']

# %%
model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(effort,grade)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
hours=float(input('Enter number of hours studied: '))
assignments=float(input('Enter number of assignment completed: '))

new_grade=pd.DataFrame([[hours,assignments]],columns=['Hours_Studied','Assignments_Completed'])
pred_grade=model.predict(new_grade)
print(f'{hours} hours studied with {assignments} assignments completed, is likely to get {pred_grade[0]} grade')
# Out:
# Enter number of hours studied:  5
# Enter number of assignment completed:  5
# 5.0 hours studied with 5.0 assignments completed, is likely to get A grade
